# %%
#| default_exp get_data

# %% [raw]
# ---
# ---
# description: A simple API allowing air quality data to be read into notebook
# output-file: get_data.html
# title: get_data
#
# ---

# %%
#| hide
import pandas as pd
from nbdev.showdoc import *
from fastcore.test import *
from fastcore.utils import *

# %%
#| export 

def get_data(link, variable_name):
    
    '''a function which takes a web link
             and read into a local file '''

    variable_name = pd.read_csv(link)
    return variable_name

# %% [markdown]
# A simple function for reading in a csv file from the web

# %%
#| echo: false
#| output: asis
show_doc(get_data)
# Out:
# ---
#
# ### get_data
#
# >      get_data (link, variable_name)
#
# a function which takes a web link
# and read into a local file

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
