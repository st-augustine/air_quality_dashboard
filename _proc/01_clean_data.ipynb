# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| hide
import pandas as pd

# %% [markdown]
# A simple function for reading in a csv file from the web

# %%
def get_data(link, variable_name):
    
    '''a function which takes a web link
             and read into a local file '''

    variable_name = pd.read_csv(link)
    return variable_name
